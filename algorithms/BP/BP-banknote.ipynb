# %% [markdown]
# ## Load dataset

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc, accuracy_score
import matplotlib.pyplot as plt


X_train_banknote = pd.read_csv("../../input/A2-banknote/banknote_X_train.csv")
X_test_banknote = pd.read_csv("../../input/A2-banknote/banknote_X_test.csv")
y_train_banknote = pd.read_csv("../../input/A2-banknote/banknote_y_train.csv")
y_test_banknote = pd.read_csv("../../input/A2-banknote/banknote_y_test.csv")

# %% [markdown]
# ## Functions for training and evaluation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, roc_curve, auc, accuracy_score
import matplotlib.pyplot as plt

# Function for training and evaluating the model
def train_and_evaluate(X_train, y_train, X_test, y_test, dataset_name):
    param_grid = {
    'hidden_layer_sizes': [(50,), (100, 50), (100,)],  # Trying different architectures
    'learning_rate_init': [0.001, 0.005],              # Adjusting learning rates
    'alpha': [0.0001, 0.001],                          # Adding L2 regularization
    'max_iter': [500, 1000]                            # Varying the number of iterations
}


    mlp = MLPClassifier(solver='adam', random_state=42)
    grid_search = GridSearchCV(mlp, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train.values.ravel())

    print(f"\nBest parameters for {dataset_name}:", grid_search.best_params_)
    print(f"Best score (accuracy) for {dataset_name}:", grid_search.best_score_)

    best_model = grid_search.best_estimator_
    y_pred_test = best_model.predict(X_test)

    conf_matrix = confusion_matrix(y_test, y_pred_test)
    print(f"Confusion Matrix for {dataset_name}:\n", conf_matrix)

    plot_roc_curve_and_auc(y_test, y_pred_test, dataset_name)
    return best_model

# Function to plot ROC curve and calculate AUC
def plot_roc_curve_and_auc(y_val, y_pred, title):
    fpr, tpr, thresholds = roc_curve(y_val, y_pred)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic (ROC) Curve - {title}')
    plt.legend(loc="lower right")
    plt.show()

    print(f"ROC AUC Score for {title}: ", roc_auc)
    accuracy = accuracy_score(y_val, y_pred)
    print(f"Accuracy for {title}: ", accuracy)
    classification_error = 1 - accuracy
    print(f"Classification Error for {title}: ", classification_error)

# %% [markdown]
# ## Cross-validation

# %%
from sklearn.model_selection import cross_val_score

# Define the model (using the best parameters found, if available)
mlp_cv = MLPClassifier(hidden_layer_sizes=(100,), learning_rate_init=0.01, max_iter=1000, random_state=42)

# Perform k-fold cross-validation
cv_scores = cross_val_score(mlp_cv, X_train_banknote, y_train_banknote.values.ravel(), cv=5, scoring='accuracy')

# Calculate average classification error in cross-validation
cv_classification_error = np.mean(1 - cv_scores)
print(f"Average Classification Error (Cross-Validation): {cv_classification_error}")
# Out:
# Average Classification Error (Cross-Validation): 0.0

# %% [markdown]
# ## Train and Evaluate the Model for the Banknote Authentication Dataset

# %%
# Train and evaluate the model on test data
best_model_banknote = train_and_evaluate(X_train_banknote, y_train_banknote, X_test_banknote, y_test_banknote, "Banknote Authentication")

# Calculate classification error on the test set
test_accuracy = best_model_banknote.score(X_test_banknote, y_test_banknote)
test_classification_error = 1 - test_accuracy
print(f"Classification Error (Test Set): {test_classification_error}")

# Compare with cross-validation error
print(f"Comparison of Errors - CV Error: {cv_classification_error}, Test Error: {test_classification_error}")
# Out:
# Best parameters for Banknote Authentication: {'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'max_iter': 500}
# Best score (accuracy) for Banknote Authentication: 1.0
# Confusion Matrix for Banknote Authentication:
#  [[148   0]
#  [  0 127]]
# ROC AUC Score for Banknote Authentication:  1.0
# Accuracy for Banknote Authentication:  1.0
# Classification Error for Banknote Authentication:  0.0
# Classification Error (Test Set): 0.0
# Comparison of Errors - CV Error: 0.0, Test Error: 0.0
